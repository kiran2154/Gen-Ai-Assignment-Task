# %% [markdown]
# ## **2.1** **LLMs and Chat Models**
#
# **💡 Concept**
# - LLMs are the core reasoning engines that generate responses.
#
# **❓ Why Needed**
#
# - They provide natural language understanding and generation.
#
# **💻 Code Example**

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7
)

response = llm.invoke("Explain LangChain in one line")
print(response.content)

# %% [markdown]
# # **2.2 Prompts and Prompt Templates**
# **💡 Concept**
#
# - Prompts define how input is structured before sending to LLM.
#
# **❓ Why Needed**
#
# - Ensures consistency and reusability.
#
# **💻 Code**

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

print(template.format(topic="LangChain"))
# Out:
# Explain LangChain in simple terms

# %% [markdown]
# # **2.3 Chains**
#
# **💡 Concept**
#
# - Chains combine multiple steps into a pipeline.
#
# **❓ Why Needed**
#
# - Real-world tasks require multi-step reasoning.
#
# **💻 Code**

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=template)
print(chain.run("Generative AI"))

# %% [markdown]
# # **2.4 Memory**
# **💡 Concept**
#
# - Memory allows systems to retain conversation context.
#
# **❓ Why Needed**
#
# - Enables chatbots and assistants.
#
# **💻 Code**

# %%
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationChain

memory = ConversationBufferMemory()

conversation = ConversationChain(
    llm=llm,
    memory=memory
)

print(conversation.run("Hi, I am Sagar"))
print(conversation.run("What is my name?"))

# %% [markdown]
# # **2.5 Tools**
# **💡 Concept**
#
# - Tools allow LLMs to interact with external systems.
#
# **❓ Why Needed**
#
# - LLMs alone cannot fetch real-time data.
#
# **💻 Code**

# %%
from langchain.tools import Tool

def calculator_tool(x):
    return eval(x)

tool = Tool(
    name="Calculator",
    func=calculator_tool,
    description="Performs math calculations"
)

# %% [markdown]
# # **2.6 Agents**
# **💡 Concept**
#
# - Agents decide which tool to use and when.
#
# **❓ Why Needed**
#
# - For dynamic decision-making.
#
# **💻 Code**

# %%
from langchain.agents import initialize_agent

agent = initialize_agent(
    tools=[tool],
    llm=llm,
    agent="zero-shot-react-description",
    verbose=True
)

agent.run("What is 25 * 4?")

# %% [markdown]
# # **2.8 Vector Stores (Indexes)**
# **💡 Concept**
#
# - Stores embeddings for semantic search.
#
# **❓ Why Needed**
#
# - Used in Retrieval-Augmented Generation (RAG).
#
# **💻 Code**

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

db = FAISS.from_documents(documents, OpenAIEmbeddings())
retriever = db.as_retriever()
